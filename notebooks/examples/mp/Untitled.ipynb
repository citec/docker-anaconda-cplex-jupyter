# %%
import sys
print(sys.modules)
# Out:
# {'lzma': <module 'lzma' from '/opt/conda/lib/python3.5/lzma.py'>, 'prompt_toolkit.interface': <module 'prompt_toolkit.interface' from '/opt/conda/lib/python3.5/site-packages/prompt_toolkit/interface.py'>, 'email': <module 'email' from '/opt/conda/lib/python3.5/email/__init__.py'>, 'multiprocessing': <module 'multiprocessing' from '/opt/conda/lib/python3.5/multiprocessing/__init__.py'>, 'prompt_toolkit.application': <module 'prompt_toolkit.application' from '/opt/conda/lib/python3.5/site-packages/prompt_toolkit/application.py'>, 'imp': <module 'imp' from '/opt/conda/lib/python3.5/imp.py'>, '_weakref': <module '_weakref' (built-in)>, 'IPython.lib.security': <module 'IPython.lib.security' from '/opt/conda/lib/python3.5/site-packages/IPython/lib/security.py'>, 'IPython.core.usage': <module 'IPython.core.usage' from '/opt/conda/lib/python3.5/site-packages/IPython/core/usage.py'>, 'argparse': <module 'argparse' from '/opt/conda/lib/python3.5/argparse.py'>, 'traitlets._version': <module 'tr
# ...
